# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data_text1.csv')

# %%
df
# Out:
#     Roll_No.     Name       Trade  Marks          City
# 0          1    Sneha        Copa     30        Vransi
# 1          2     aman      Fitter     50        Kanpur
# 2          3     alok  Electricen     40       Gazipur
# 3          4     arun        copa     35        Junpur
# 4          5    kajal      fitter     84      cholapur
# 5          6    mohit        copa     57  palahi patti
# 6          7  Vinayak  Electricen     69        Nahiya
# 7          8    Sanvi  Electricen     48      Sonbhadr
# 8          9     Abhi        copa     78        Baliya
# 9         10    Kavya        Copa     95       Magariy
# 10        11   Aayush      fitter     46      Varanasi
# 11        12     Ansh         NaN     76        Kanpur

# %%
df["Marks"]
# Out:
# 0     30
# 1     50
# 2     40
# 3     35
# 4     84
# 5     57
# 6     69
# 7     48
# 8     78
# 9     95
# 10    46
# 11    76
# Name: Marks, dtype: int64

# %%
df["Name"]
# Out:
# 0       Sneha
# 1        aman
# 2        alok
# 3        arun
# 4       kajal
# 5       mohit
# 6     Vinayak
# 7       Sanvi
# 8        Abhi
# 9       Kavya
# 10     Aayush
# 11       Ansh
# Name: Name, dtype: str

# %%
y=df["Marks"]
x=df["Name"]

# %%
plt.figure(figsize=(13,5))
plt.bar(x,y)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,marker='o',markerfacecolor='red',markeredgecolor='green',markersize=10)

# %%
df["Trade"]
# Out:
# 0           Copa
# 1         Fitter
# 2     Electricen
# 3           copa
# 4         fitter
# 5           copa
# 6     Electricen
# 7     Electricen
# 8           copa
# 9           Copa
# 10        fitter
# 11           NaN
# Name: Trade, dtype: str

# %%
avg=df.groupby("Trade")["Marks"].mean()
# Out:
# Trade
# Copa          62.500000
# Electricen    52.333333
# Fitter        50.000000
# copa          56.666667
# fitter        65.000000
# Name: Marks, dtype: float64

# %%
x=df["Marks"]
y=df["Trade"]

# %%
plt.bar(avg.index,avg.values)
# Out:
# <BarContainer object of 5 artists>
