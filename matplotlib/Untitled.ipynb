# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[10,20,30,40,50]

# %%
plt.plot(x,y)

# %%
plt.show()

# %%
subject=["Hindi","English","Math","Science","History","Geograph","Drawing","HomeScience","computer","sanskrit"]
marks=[50,40,30,20,10,60,70,80,90,100]

# %%
plt.title("Subject marks line chart")
plt.ylabel("marks") vb
plt.xlabel("subject")
plt.figure(figsize=(13,5))
plt.bar(subject,marks)
# Out:
# <BarContainer object of 10 artists>

# %%
marks=[10,20,30,40,50]
subject=["Hindi","English","Math","Science","History"]

# %%
plt.title("data pie chart")
plt.pie(marks,labels=marks)
# Out:
# ([<matplotlib.patches.Wedge at 0x1765750c050>,
# ...
#  [Text(1.0759623560663252, 0.22870288220353185, '10'),
#   Text(0.7360435992131525, 0.8174593690559478, '20'),
#   Text(-0.339918873399729, 1.0461621095732052, '30'),
#   Text(-1.0759622304262273, -0.22870347329286142, '40'),
#   Text(0.5500008201747041, -0.9526274706343256, '50')])

# %%
plt.title("data Scatter chart")
plt.scatter(subject,marks)

# %%
plt.hist(marks,bins=5)
# Out:
# (array([1., 1., 1., 1., 1.]),
#  array([10., 18., 26., 34., 42., 50.]),
#  <BarContainer object of 5 artists>)
