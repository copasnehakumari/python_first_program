# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=[10,20,30,40,50]

# %%
sns.histplot(data)
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd

# %%
df=pd.read_csv('task.csv')

# %%
df
# Out:
#      NAME  MATH  SCIENCE  HINDI  COMPUTER
# 0   sneha    25       72     29        45
# 1    aman    36       65     35        79
# 2  saloni    50       49     51        53
# 3   aditi    44       85     65        65
# 4   sonam    62       26     25        58
# 5  antima    95       43     84        39
# 6  shakti    78       54     79        49
# 7    ruby    63       36     85        63
# 8   mohit    41       66     45        52
# 9    abhi    85       33     46        97

# %%
sns.barplot(x='NAME',y='COMPUTER',data=df)
# Out:
# <Axes: xlabel='NAME', ylabel='COMPUTER'>

# %%
sns.pairplot(df.drop("NAME",axis=1))

# %%
sns.heatmap(df.set_index('NAME'),annot=True,cmap="coolwarm")
# Out:
# <Axes: ylabel='NAME'>

# %%
sns.lineplot(x='NAME',y='COMPUTER',data=df)
# Out:
# <Axes: xlabel='NAME', ylabel='COMPUTER'>
