# %%
import pandas as pd
dict={"name":['shakti','neha','ansh'],
      "makrs":[10,30,40],
       "city":['varanasi','obra','kanpur'],
        }
df=pd.DataFrame(dict)
# Out:
#      name  makrs      city
# 0  shakti     10  varanasi
# 1    neha     30      obra
# 2    ansh     40    kanpur

# %%
df.to_csv('data.csv',index=False)

# %%
df.head(2)
# Out:
#      name  makrs      city
# 0  shakti     10  varanasi
# 1    neha     30      obra

# %%
df.tail(2)
# Out:
#    name  makrs    city
# 1  neha     30    obra
# 2  ansh     40  kanpur

# %%
df.loc[1]
# Out:
# name     neha
# makrs      30
# city     obra
# Name: 1, dtype: object

# %%
df.loc[1,"city"]
# Out:
# 'obra'
