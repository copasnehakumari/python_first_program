# %%
# this is test code

# %%
a=10
b=40
a*b
# Out:
# 400

# %%
import pandas as pd
data=[10,20,30,40]
s=pd.Series(data)
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
data=[10,20,30,40]
s=pd.Series(data,index=['a','b','c','d'])
s
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
import pandas as pd
data=[10,20,30,40]
s=pd.Series(data)
(s.sum())
# Out:
# np.int64(100)

# %%
import pandas as pd
dict={"Name":['aman','sneha','alok'],
     "Marks":[20,30,40,],
     "City":['varanasi','kanpur','gaziput'],
     "Trade":['copa','fdt','fitter']
    }
df=pd.DataFrame(dict)

# %%
df.to_csv('data1.csv',index=False)

# %%
df.head(2)
# Out:
#     Name  Marks      City Trade
# 0   aman     20  varanasi  copa
# 1  sneha     30    kanpur   fdt

# %%
df.tail(2)
# Out:
#     Name  Marks     City   Trade
# 1  sneha     30   kanpur     fdt
# 2   alok     40  gaziput  fitter

# %%
df.loc[1,"Trade"]
# Out:
# 'fdt'
