# %%
import pandas as pd

# %%
df=pd.read_csv('data_text1.csv')

# %%
df
# Out:
#     Roll_No.     Name       Trade  Marks          City
# 0          1    Sneha        Copa     30        Vransi
# 1          2     aman      Fitter     50        Kanpur
# 2          3     alok  Electricen     40       Gazipur
# 3          4     arun        copa     35        Junpur
# 4          5    kajal      fitter     84      cholapur
# 5          6    mohit        copa     57  palahi patti
# 6          7  Vinayak  Electricen     69        Nahiya
# 7          8    Sanvi  Electricen     48      Sonbhadr
# 8          9     Abhi        copa     78        Baliya
# 9         10    Kavya        Copa     95       Magariy
# 10        11   Aayush      fitter     46      Varanasi
# 11        12     Ansh         NaN     76        Kanpur

# %%
len(df)
# Out:
# 12

# %%
df.head(3)
# Out:
#    Roll_No.   Name       Trade  Marks     City
# 0         1  Sneha        Copa     30   Vransi
# 1         2   aman      Fitter     50   Kanpur
# 2         3   alok  Electricen     40  Gazipur

# %%
df.tail(3)
# Out:
#     Roll_No.    Name   Trade  Marks      City
# 9         10   Kavya    Copa     95   Magariy
# 10        11  Aayush  fitter     46  Varanasi
# 11        12    Ansh     NaN     76    Kanpur

# %%
df["Marks"].mean()
# Out:
# np.float64(59.0)

# %%
df["Marks"].max()
# Out:
# np.int64(95)

# %%
df["Marks"].min()
# Out:
# np.int64(30)

# %%
df["Marks"]
# Out:
# 0     30
# 1     50
# 2     40
# 3     35
# 4     84
# 5     57
# 6     69
# 7     48
# 8     78
# 9     95
# 10    46
# 11    76
# Name: Marks, dtype: int64

# %%
df[df["Marks"]==df["Marks"].max()]
# Out:
#    Roll_No.   Name Trade  Marks     City
# 9        10  Kavya  Copa     95  Magariy

# %%
df[df["Marks"]==df["Marks"].min()]
# Out:
#    Roll_No.   Name Trade  Marks    City
# 0         1  Sneha  Copa     30  Vransi

# %%
df[df["Trade"]=="Copa"]
# Out:
#    Roll_No.   Name Trade  Marks     City
# 0         1  Sneha  Copa     30   Vransi
# 9        10  Kavya  Copa     95  Magariy

# %%
len(df[df["Trade"]=="Electricen"])
# Out:
# 3

# %%
df["Trade"].value_counts()
# Out:
# Trade
# Electricen    3
# copa          3
# Copa          2
# fitter        2
# Fitter        1
# Name: count, dtype: int64

# %%
df[df["Marks"]>80]
# Out:
#    Roll_No.   Name   Trade  Marks      City
# 4         5  kajal  fitter     84  cholapur
# 9        10  Kavya    Copa     95   Magariy

# %%
df.groupby("Trade")["Marks"].min()
# Out:
# Trade
# Copa          30
# Electricen    40
# Fitter        50
# copa          35
# fitter        46
# Name: Marks, dtype: int64

# %%
df.sort_values(by="Marks",ascending=False)
# Out:
#     Roll_No.     Name       Trade  Marks          City
# 9         10    Kavya        Copa     95       Magariy
# 4          5    kajal      fitter     84      cholapur
# 8          9     Abhi        copa     78        Baliya
# 11        12     Ansh         NaN     76        Kanpur
# 6          7  Vinayak  Electricen     69        Nahiya
# 5          6    mohit        copa     57  palahi patti
# 1          2     aman      Fitter     50        Kanpur
# 7          8    Sanvi  Electricen     48      Sonbhadr
# 10        11   Aayush      fitter     46      Varanasi
# 2          3     alok  Electricen     40       Gazipur
# 3          4     arun        copa     35        Junpur
# 0          1    Sneha        Copa     30        Vransi

# %%
df.sort_values(by="Marks",ascending=True)
# Out:
#     Roll_No.     Name       Trade  Marks          City
# 0          1    Sneha        Copa     30        Vransi
# 3          4     arun        copa     35        Junpur
# 2          3     alok  Electricen     40       Gazipur
# 10        11   Aayush      fitter     46      Varanasi
# 7          8    Sanvi  Electricen     48      Sonbhadr
# 1          2     aman      Fitter     50        Kanpur
# 5          6    mohit        copa     57  palahi patti
# 6          7  Vinayak  Electricen     69        Nahiya
# 11        12     Ansh         NaN     76        Kanpur
# 8          9     Abhi        copa     78        Baliya
# 4          5    kajal      fitter     84      cholapur
# 9         10    Kavya        Copa     95       Magariy

# %%
df["Marks"]=[10,52,20,25,33,17,81,80,99,100,38,22]

# %%
df
# Out:
#     Roll_No.     Name       Trade  Marks          City
# 0          1    Sneha        Copa     10        Vransi
# 1          2     aman      Fitter     52        Kanpur
# 2          3     alok  Electricen     20       Gazipur
# 3          4     arun        copa     25        Junpur
# 4          5    kajal      fitter     33      cholapur
# 5          6    mohit        copa     17  palahi patti
# 6          7  Vinayak  Electricen     81        Nahiya
# 7          8    Sanvi  Electricen     80      Sonbhadr
# 8          9     Abhi        copa     99        Baliya
# 9         10    Kavya        Copa    100       Magariy
# 10        11   Aayush      fitter     38      Varanasi
# 11        12     Ansh         NaN     22        Kanpur

# %%
df.loc[2,"Marks"]=[10]

# %%
df
# Out:
#     Roll_No.     Name       Trade  Marks          City
# 0          1    Sneha        Copa     10        Vransi
# 1          2     aman      Fitter     52        Kanpur
# 2          3     alok  Electricen     10       Gazipur
# 3          4     arun        copa     25        Junpur
# 4          5    kajal      fitter     33      cholapur
# 5          6    mohit        copa     17  palahi patti
# 6          7  Vinayak  Electricen     81        Nahiya
# 7          8    Sanvi  Electricen     80      Sonbhadr
# 8          9     Abhi        copa     99        Baliya
# 9         10    Kavya        Copa    100       Magariy
# 10        11   Aayush      fitter     38      Varanasi
# 11        12     Ansh         NaN     22        Kanpur
