# %%
import pandas as pd

# %%
df=pd.read_csv('sk.csv')

# %%
df
# Out:
#       Name            Pordect    price     Total
# 0     Amit            monitor    200.0    4000.0
# 1    Rohit           keyboard    150.0    1500.0
# 2    Suman                ram    100.0    1200.0
# 3     Neha        motherboard    300.0    4500.0
# 4    Pooja              mouse    200.0    2000.0
# 5    Rahul                 cd    100.0    1300.0
# 6    Vikas                hdd    200.0    3600.0
# 7    Anita                dvd    170.0    1870.0
# 8    Karan                ssd    250.0    4500.0
# 9    Priya            printer    500.0    4000.0
# 10  Deepak            scanner    700.0    4200.0
# 11    Rani            speaker    150.0    2100.0
# 12   Manoj             webcam    300.0    2700.0
# 13  Kavita             laptop  40000.0  200000.0
# 14  Sanjay             tablet  15000.0  105000.0
# 15   Rekha            charger    200.0    4000.0
# 16   Arjun           pendrive    300.0    7500.0
# 17  Sunita             router   1200.0   12000.0
# ...
